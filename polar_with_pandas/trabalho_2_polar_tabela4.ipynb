# %%
import pandas as pd

df = pd.read_csv("dados_tabela_4.csv")
df.head()
# Out:
#   Nome da Via/Taxa De Emissão de Poluentes   MP10   SO2   Nox    CO    HC
# 0                               Av. Brasil   22.9  30.0  33.4  25.3  25.2
# 1                         Av. das Américas    5.7   9.6   7.9  12.2  12.3
# 2                         Rod. Pres. Dutra    5.5   2.9   3.4   2.6   2.2
# 3                           Linha Vermelha    3.1   3.4   3.8   2.8   2.8
# 4                     Rod. Washington Luís    2.9   3.9   4.2   3.5   3.5

# %%
df = df.rename(index=str, columns={' SO2':'SO2', ' Nox':'Nox',' CO':'CO',' HC':'HC',' MP10':'MP10'})
df.columns.values
# Out:
# array(['Nome da Via/Taxa De Emissão de Poluentes', 'MP10', 'SO2', 'Nox',
#        'CO', 'HC'], dtype=object)

# %%
df.set_index(['Nome da Via/Taxa De Emissão de Poluentes'])
# Out:
#                                           MP10   SO2   Nox    CO    HC
# Nome da Via/Taxa De Emissão de Poluentes
# Av. Brasil                                22.9  30.0  33.4  25.3  25.2
# Av. das Américas                           5.7   9.6   7.9  12.2  12.3
# Rod. Pres. Dutra                           5.5   2.9   3.4   2.6   2.2
# Linha Vermelha                             3.1   3.4   3.8   2.8   2.8
# Rod. Washington Luís                       2.9   3.9   4.2   3.5   3.5
# Ponte Rio - Niterói                        1.9   3.2   2.7   3.9   3.9
# Av. Ayrton Sena                            NaN   2.2   1.8   2.9   2.9
# Linha Amarela                              NaN   1.9   1.9   2.5   2.5
# Demais Vias                               58.0  42.9  40.9  44.3  44.7

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set('paper', 'white', 'colorblind', font_scale=2.2, 
            rc={'lines.linewidth': 2, 
                'figure.figsize': (12.0, 10.0), 
                'image.interpolation': 'nearest', 
                'image.cmap': 'gray'})

plt.rcParams['figure.figsize'] = (12.0, 10.0) 
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
plt.rcParams['xtick.labelsize'] = 15
plt.rcParams['ytick.labelsize'] = 15

# %%
sns.barplot(x="Nome da Via/Taxa De Emissão de Poluentes", y="MP10", data=df)

plt.ylabel("Taxa de Emissão (x1000 ton/ano)")
plt.xlabel("Nome da via")

plt.xticks(rotation=45)

mean_poluente = df["MP10"].mean()
plt.axhline(mean_poluente,label='Média', linestyle='--')
legend = plt.legend(loc='upper left')

plt.savefig('tabela_4_MP10.png')
mean_poluente
# Out:
# 14.285714285714286

# %%
sns.barplot(x="Nome da Via/Taxa De Emissão de Poluentes", y="SO2", data=df)

plt.ylabel("Taxa de Emissão (x1000 ton/ano)")
plt.xlabel("Nome da via")

plt.xticks(rotation=45)

mean_poluente = df["SO2"].mean()
plt.axhline(mean_poluente,label='Média', linestyle='--')
legend = plt.legend(loc='upper left')

plt.savefig('tabela_4_SO2.png')
mean_poluente
# Out:
# 11.11111111111111

# %%
sns.barplot(x="Nome da Via/Taxa De Emissão de Poluentes", y="Nox", data=df)

plt.ylabel("Taxa de Emissão (x1000 ton/ano)")
plt.xlabel("Nome da via")

plt.xticks(rotation=45)

mean_poluente = df["Nox"].mean()
plt.axhline(mean_poluente,label='Média', linestyle='--')
legend = plt.legend(loc='upper left')

plt.savefig('tabela_4_Nox.png')
mean_poluente
# Out:
# 11.11111111111111

# %%
sns.barplot(x="Nome da Via/Taxa De Emissão de Poluentes", y="CO", data=df)

plt.ylabel("Taxa de Emissão (x1000 ton/ano)")
plt.xlabel("Nome da via")

plt.xticks(rotation=45)

mean_poluente = df["CO"].mean()
plt.axhline(mean_poluente,label='Média', linestyle='--')
legend = plt.legend(loc='upper left')

plt.savefig('tabela_4_CO.png')
mean_poluente
# Out:
# 11.11111111111111

# %%
sns.barplot(x="Nome da Via/Taxa De Emissão de Poluentes", y="HC", data=df)

plt.ylabel("Taxa de Emissão (x1000 ton/ano)")
plt.xlabel("Nome da via")

plt.xticks(rotation=45)

mean_poluente = df["HC"].mean()
plt.axhline(mean_poluente,label='Média', linestyle='--')
legend = plt.legend(loc='upper left')

plt.savefig('tabela_4_HC.png')
mean_poluente
# Out:
# 11.11111111111111
